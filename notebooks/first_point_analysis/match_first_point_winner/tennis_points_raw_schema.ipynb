# %%
from pyspark.sql.types import *

tennis_schema = StructType([
    StructField("match_id", StringType(), True),
    StructField("ElapsedTime", StringType(), True),
    StructField("SetNo", IntegerType(), True),
    StructField("P1GamesWon", IntegerType(), True),
    StructField("P2GamesWon", IntegerType(), True),
    StructField("SetWinner", IntegerType(), True),
    StructField("GameNo", IntegerType(), True),
    StructField("GameWinner", IntegerType(), True),
    StructField("PointNumber", StringType(), True),
    StructField("PointWinner", IntegerType(), True),
    StructField("PointServer", IntegerType(), True),
    StructField("Speed_KMH", IntegerType(), True),
    StructField("Rally", StringType(), True),
    StructField("P1Score", StringType(), True),
    StructField("P2Score", StringType(), True),
    StructField("P1Momentum", IntegerType(), True),
    StructField("P2Momentum", IntegerType(), True),
    StructField("P1PointsWon", IntegerType(), True),
    StructField("P2PointsWon", IntegerType(), True),
    StructField("P1Ace", IntegerType(), True),
    StructField("P2Ace", IntegerType(), True),
    StructField("P1Winner", IntegerType(), True),
    StructField("P2Winner", IntegerType(), True),
    StructField("P1DoubleFault", IntegerType(), True),
    StructField("P2DoubleFault", IntegerType(), True),
    StructField("P1UnfErr", IntegerType(), True),
    StructField("P2UnfErr", IntegerType(), True),
    StructField("P1NetPoint", IntegerType(), True),
    StructField("P2NetPoint", IntegerType(), True),
    StructField("P1NetPointWon", IntegerType(), True),
    StructField("P2NetPointWon", IntegerType(), True),
    StructField("P1BreakPoint", IntegerType(), True),
    StructField("P2BreakPoint", IntegerType(), True),
    StructField("P1BreakPointWon", IntegerType(), True),
    StructField("P2BreakPointWon", IntegerType(), True),
    StructField("P1FirstSrvIn", StringType(), True),
    StructField("P2FirstSrvIn", StringType(), True),
    StructField("P1FirstSrvWon", StringType(), True),
    StructField("P2FirstSrvWon", StringType(), True),
    StructField("P1SecondSrvIn", StringType(), True),
    StructField("P2SecondSrvIn", StringType(), True),
    StructField("P1SecondSrvWon", StringType(), True),
    StructField("P2SecondSrvWon", StringType(), True),
    StructField("P1ForcedError", StringType(), True),
    StructField("P2ForcedError", StringType(), True),
    StructField("History", IntegerType(), True),
    StructField("Speed_MPH", IntegerType(), True),
    StructField("P1BreakPointMissed", IntegerType(), True),
    StructField("P2BreakPointMissed", IntegerType(), True),
    StructField("ServeIndicator", IntegerType(), True),
    StructField("Serve_Direction", StringType(), True),
    StructField("Winner_FH", StringType(), True),
    StructField("Winner_BH", StringType(), True),
    StructField("ServingTo", StringType(), True),
    StructField("P1TurningPoint", StringType(), True),
    StructField("P2TurningPoint", StringType(), True),
    StructField("ServeNumber", IntegerType(), True),
    StructField("WinnerType", StringType(), True),
    StructField("WinnerShotType", StringType(), True),
    StructField("P1DistanceRun", DoubleType(), True),
    StructField("P2DistanceRun", DoubleType(), True),
    StructField("RallyCount", IntegerType(), True),
    StructField("ServeWidth", StringType(), True),
    StructField("ServeDepth", StringType(), True),
    StructField("ReturnDepth", StringType(), True)
])
